# %%
# Parse data exported in xml from ClinicalTrials.gov 
# Pull "detailed description", arms and interventions" and "eligibility criteria"
# Mary Kate Montgomery

# %%
# Import libraries
import xmltodict as xml
import pandas as pd

# %%
# Read csv
df = pd.read_csv('new_data/ClinicalTrialsGov-Pacemaker.csv')
df.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04926792             Taiwan Registry for Leadless Pacemaker
# 1     2  NCT02931760  Placement Of Cardiac PacemaKer Trial (POCKET)-RCT
# 2     3  NCT03876600  Cost-utility Analysis of Ambulatory Care Compa...
# 3     4  NCT03388281  Morbidity, Mortality and Gender Differences in...
# 4     5  NCT04163770               Evaluation Of Pacemakers in Children
#
#       Acronym              Status         Study Results  \
# 0         NaN  Not yet recruiting  No Results Available
# 1  POCKET-RCT      Unknown status  No Results Available
# 2       START  Not yet recruiting  No Results Available
# 3         NaN           Completed  No Results Available
# 4         NaN      Unknown status  No Results Available
#
#                                           Conditions  \
# 0  Performance of the Leadless Pacemaker in Taiwa...
# 1                                      Pacemaker Ddd
# 2                                      Pacemaker Ddd
# 3  Pacemaker, Artificial|Cohort Studies|Arrhythmi...
# 4               Disorder of Cardiac Pacemaker System
#
#                                        Interventions  \
# 0                         Device: Leadless Pacemaker
# 1  Device: subcutaneous pacemaker|Device: intramu...
# 2  Procedure: Replacement of permanent pacemakers...
# 3  Other: No intervention, retrospective analysis...
# 4                  Device: caliberation of pacemaker
#
#                                     Outcome Measures  \
# 0  Acute complication|Subacute complication|Leadl...
# 1  patient overall satisfaction|complications due...
# 2  Cost-utility analysis,from the perspective of ...
# 3  Survival after pacemaker implantation|Implanta...
# 4              Performance of pacemakers in children
#
#                                Sponsor/Collaborators  ...      Other IDs  \
# 0  National Taiwan University Hospital|Taiwan Soc...  ...  202103105RINB
# 1                                   Region Gävleborg  ...        2016371
# 2  Nantes University Hospital|Ministry of Health,...  ...      RC18_0034
# 3                       Medical University of Vienna  ...    EK1525/2015
# 4                                  Assiut University  ...           EPCP
#
#          Start Date Primary Completion Date    Completion Date  \
# 0         July 2021               June 2024          June 2025
# 1      October 2016           December 2017          June 2019
# 2        April 2019              April 2022         April 2022
# 3     July 28, 2015          March 31, 2016     March 31, 2016
# 4  January 15, 2020        January 15, 2021  February 15, 2021
#
#         First Posted Results First Posted Last Update Posted  \
# 0      June 15, 2021                  NaN      June 15, 2021
# 1   October 13, 2016                  NaN   October 13, 2016
# 2     March 15, 2019                  NaN     March 15, 2019
# 3    January 2, 2018                  NaN    January 2, 2018
# 4  November 15, 2019                  NaN  November 15, 2019
#
#                                            Locations Study Documents  \
# 0                                                NaN             NaN
# 1                    Region Gavleborg, Gävle, Sweden             NaN
# 2  Lyon University Hospital, Lyon, Bron, France|A...             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#                                            URL
# 0  https://ClinicalTrials.gov/show/NCT04926792
# 1  https://ClinicalTrials.gov/show/NCT02931760
# 2  https://ClinicalTrials.gov/show/NCT03876600
# 3  https://ClinicalTrials.gov/show/NCT03388281
# 4  https://ClinicalTrials.gov/show/NCT04163770
#
# [5 rows x 27 columns]

# %%
def readXml(row):
    id = row['NCT Number']

    # Initialize with empty values
    row['Detailed Description'] = ''
    row['Study Arms'] = ''
    row['Eligibility Criteria'] = ''
    
    # Read file into dict
    with open('Pacemaker/ClinTrials_XML/'+id+'.xml') as fd:
        doc = xmltodict.parse(fd.read())
        
    if 'clinical_study' not in doc.keys():
        return row
        
    # Get detailed description
    if 'detailed_description' in doc['clinical_study'].keys():
        row['Detailed Description'] = doc['clinical_study']['detailed_description']['textblock']

    # Get arms and interventions
    if 'arm_group' in doc['clinical_study'].keys():
        if type(doc['clinical_study']['arm_group']) == list:
            num_arms = len(doc['clinical_study']['arm_group'])
            arm_labels = []; 
            for i in range(num_arms):
                arm_labels.append(doc['clinical_study']['arm_group'][i]['arm_group_label'])
        else:
            arm_labels = doc['clinical_study']['arm_group']['arm_group_label']    
        
        row['Study Arms'] = arm_labels
    
    # Get eligibility criteria
    if 'eligibility' in doc['clinical_study'].keys() and 'criteria' in doc['clinical_study']['eligibility'].keys():
        row['Eligibility Criteria'] = doc['clinical_study']['eligibility']['criteria']['textblock']
    
    return row

df = df.apply(lambda row: readXml(row),axis=1)

# %%
# Write data to csv
df.to_csv('new_data/ClinicalTrialsGov-Pacemaker-wContent.csv')
